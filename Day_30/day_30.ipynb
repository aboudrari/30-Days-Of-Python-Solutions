# %% [markdown]
# ****Conclusions****
#
# This wraps up the 30 Days Of Python challenge — from variables and strings all the way to APIs, web scraping and databases.

# %% [markdown]
# ***What was covered***
#
# - Core language: variables, data types, operators, strings, lists, tuples, sets, dictionaries
# - Control flow: conditionals, loops
# - Functions: regular, higher-order, lambda, list comprehension
# - Programming fundamentals: modules, exception handling, regular expressions, file handling
# - Tooling: pip, virtual environments
# - Object-oriented programming: classes and objects
# - Data & the web: statistics, pandas, web scraping, APIs, building an API, MongoDB

# %% [markdown]
# ***Reflection exercises (no right answers — just write freely)***

# %%
# 1. Which day's topic did you find the most challenging, and why?

# %%
# 2. Which day's topic do you think will be the most useful in your future projects?

# %%
# 3. Pick one exercise you solved and explain, in your own words, how you approached it

# %%
# 4. What would you like to learn next, now that you've finished this challenge?

# %%
# 5. Write a short project idea that combines at least 3 topics from this challenge (e.g. file handling + API + pandas)
