# %% [markdown]
# ****Classes and Objects****

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        return f'Hello, my name is {self.name} and I am {self.age} years old'

p = Person('Abdallah', 25)
print(p.greet())
print(p.name, p.age)
# Out:
# Hello, my name is Abdallah and I am 25 years old
# Abdallah 25

# %% [markdown]
# ***Class attributes vs instance attributes***

# %%
class Person:
    species = 'Homo sapiens'  # class attribute, shared by all instances

    def __init__(self, name):
        self.name = name       # instance attribute

p1 = Person('Alice')
p2 = Person('Bob')
print(p1.species, p2.species)  # both share the same class attribute
print(p1.name, p2.name)        # each has its own instance attribute
# Out:
# Homo sapiens Homo sapiens
# Alice Bob

# %% [markdown]
# ***Instance methods, class methods and static methods***

# %%
class Circle:
    pi = 3.14159

    def __init__(self, radius):
        self.radius = radius

    def area(self):                     # instance method
        return Circle.pi * self.radius ** 2

    @classmethod
    def unit_circle(cls):               # class method
        return cls(1)

    @staticmethod
    def describe():                     # static method
        return 'A circle is a round shape'

c = Circle(3)
print(c.area())
unit = Circle.unit_circle()
print(unit.radius)
print(Circle.describe())
# Out:
# 28.27431
# 1
# A circle is a round shape

# %% [markdown]
# ***Inheritance***

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return f'{self.name} makes a sound'

class Dog(Animal):
    def speak(self):                 # method overriding
        return f'{self.name} barks'

class Cat(Animal):
    def speak(self):
        return f'{self.name} meows'

for animal in [Dog('Rex'), Cat('Whiskers'), Animal('Creature')]:
    print(animal.speak())
# Out:
# Rex barks
# Whiskers meows
# Creature makes a sound

# %% [markdown]
# ***super()***

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

d = Dog('Rex', 'German Shepherd')
print(d.name, d.breed)
# Out:
# Rex German Shepherd

# %% [markdown]
# ***Dunder methods: __str__ and __repr__***

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f'Point({self.x}, {self.y})'

p = Point(1, 2)
print(p)          # uses __str__
print(str(p))
# Out:
# Point(1, 2)
# Point(1, 2)

# %% [markdown]
# # Exercises: Day 21

# %%
# 1. Create a Person class with name, age and country attributes, and a method introduce() that returns a sentence

# %%
# 2. Create a class attribute on Person that tracks the total number of Person instances created

# %%
# 3. Create a PersonAccount class with balance, deposit() and withdraw() methods (withdraw should not allow the balance to go negative)

# %%
# 4. Create an Animal base class with a speak() method, then create Dog and Cat subclasses that override speak()

# %%
# 5. Create a Student class that inherits from Person and adds a school and a list of grades, with a method average_grade()

# %%
# 6. Add __str__ and __repr__ methods to one of your classes so printing an instance is readable

# %%
# 7. Create a Rectangle class with width and height, and methods area() and perimeter()

# %%
# 8. Create a Square class that inherits from Rectangle, using super().__init__() so width and height are equal
