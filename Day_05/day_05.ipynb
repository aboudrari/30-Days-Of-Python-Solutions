# %% [markdown]
# ****Lists****

# %%
empty_list = list()  # this is an empty list, no item in the list
print(len(empty_list))  # 0

# list of fruits
fruits = ['banana', 'orange', 'mango', 'lemon']
vegetables = ['Tomato', 'Potato', 'Cabbage',
              'Onion', 'Carrot']      # list of vegetables
animal_products = ['milk', 'meat', 'butter',
                   'yoghurt']             # list of animal products
web_techs = ['HTML', 'CSS', 'JS', 'React', 'Redux',
             'Node', 'MongDB']  # list of web technologies
countries = ['Finland', 'Estonia', 'Denmark', 'Sweden', 'Norway']
# Out:
# 0

# %% [markdown]
# ***Print the lists and it length***

# %%
# Print the lists and it length
print('Fruits:', fruits)
print('Number of fruits:', len(fruits))
print('Vegetables:', vegetables)
print('Number of vegetables:', len(vegetables))
print('Animal products:', animal_products)
print('Number of animal products:', len(animal_products))
print('Web technologies:', web_techs)
print('Number of web technologies:', len(web_techs))
print('Number of countries:', len(countries))
# Out:
# Fruits: ['banana', 'orange', 'mango', 'lemon']
# Number of fruits: 4
# Vegetables: ['Tomato', 'Potato', 'Cabbage', 'Onion', 'Carrot']
# Number of vegetables: 5
# Animal products: ['milk', 'meat', 'butter', 'yoghurt']
# Number of animal products: 4
# Web technologies: ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'MongDB']
# Number of web technologies: 7
# Number of countries: 5

# %% [markdown]
# ***Modifying list***

# %%
# Modifying list

fruits = ['banana', 'orange', 'mango', 'lemon']
first_fruit = fruits[0]  # we are accessing the first item using its index
print(first_fruit)      # banana
second_fruit = fruits[1]
print(second_fruit)     # orange
last_fruit = fruits[3]
print(last_fruit)  # lemon
# Last index
last_index = len(fruits) - 1
last_fruit = fruits[last_index]
# Out:
# banana
# orange
# lemon

# %% [markdown]
# ***Accessing itmes***

# %%
# Accessing itmes
fruits = ['banana', 'orange', 'mango', 'lemon']
last_fruit = fruits[-1]
second_last = fruits[-2]
print(last_fruit)       # lemon
print(second_last)      # mango
# Out:
# lemon
# mango

# %% [markdown]
# ***Slicing items***

# %%
# Slicing items
fruits = ['banana', 'orange', 'mango', 'lemon']
all_fruits = fruits[0:4]  # it returns all the fruits
# this is also give the same result as the above
all_fruits = fruits[0:]  # if we don't set where to stop it takes all the rest
orange_and_mango = fruits[1:3]  # it does not include the end index
orange_mango_lemon = fruits[1:]

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
all_fruits = fruits[-4:]  # it returns all the fruits
# this is also give the same result as the above
orange_and_mango = fruits[-3:-1]  # it does not include the end index
orange_mango_lemon = fruits[-3:]

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits[0] = 'Avocado'
print(fruits)  # ['avocado', 'orange', 'mango', 'lemon']
fruits[1] = 'apple'
print(fruits)  # ['avocado', 'apple', 'mango', 'lemon']
last_index = len(fruits)
#fruits[last_index] = 'lime'
print(fruits)  # ['avocado', 'apple', 'mango', 'lime']
# Out:
# ['Avocado', 'orange', 'mango', 'lemon']
# ['Avocado', 'apple', 'mango', 'lemon']
# ['Avocado', 'apple', 'mango', 'lemon']

# %% [markdown]
# ***checking items***

# %%
# checking items
fruits = ['banana', 'orange', 'mango', 'lemon']
does_exist = 'banana' in fruits
print(does_exist)  # True
does_exist = 'lime' in fruits
print(does_exist)  # False
# Out:
# True
# False

# %% [markdown]
# ***Append***

# %%
# Append
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.append('apple')
print(fruits)           # ['banana', 'orange', 'mango', 'lemon', 'apple']
# ['banana', 'orange', 'mango', 'lemon', 'apple', 'lime]
fruits.append('lime')
print(fruits)
# Out:
# ['banana', 'orange', 'mango', 'lemon', 'apple']
# ['banana', 'orange', 'mango', 'lemon', 'apple', 'lime']

# %% [markdown]
# ***insert***

# %%
# insert
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.insert(2, 'apple')  # insert apple between orange and mango
print(fruits)           # ['banana', 'orange', 'apple', 'mango', 'lemon']
# ['banana', 'orange', 'apple', 'mango', 'lime','lemon',]
fruits.insert(3, 'lime')
print(fruits)
# Out:
# ['banana', 'orange', 'apple', 'mango', 'lemon']
# ['banana', 'orange', 'apple', 'lime', 'mango', 'lemon']

# %% [markdown]
# ***remove***

# %%
# remove
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.remove('banana')
print(fruits)  # ['orange', 'mango', 'lemon']
fruits.remove('lemon')
print(fruits)  # ['orange', 'mango']
# Out:
# ['orange', 'mango', 'lemon']
# ['orange', 'mango']

# %% [markdown]
# ***pop***

# %%
# pop
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.remove('lemon')
print(fruits)       # ['banana', 'orange', 'mango']

fruits.pop(0)
print(fruits)       # ['orange', 'mango']
# Out:
# ['banana', 'orange', 'mango']
# ['orange', 'mango']

# %% [markdown]
# ***del***

# %%
# del
fruits = ['banana', 'orange', 'mango', 'lemon']
del fruits[0]
print(fruits)       # ['orange', 'mango', 'lemon']

del fruits[1]
print(fruits)       # ['orange', 'lemon']
del fruits
print(fruits)       # This should give: NameError: name 'fruits' is not defined
# Out:
# ['orange', 'mango', 'lemon']
# ['orange', 'lemon']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 9
#       7 print(fruits)       # ['orange', 'lemon']
#       8 del fruits
# ----> 9 print(fruits)       # This should give: NameError: name 'fruits' is not defined
#
# NameError: name 'fruits' is not defined

# %% [markdown]
# ***clear***

# %%
# clear
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.clear()
print(fruits)       # []
# Out:
# []

# %% [markdown]
# ***copying a lits***

# %%
# copying a lits

fruits = ['banana', 'orange', 'mango', 'lemon']
fruits_copy = fruits.copy()
print(fruits_copy)       # ['banana', 'orange', 'mango', 'lemon']
# Out:
# ['banana', 'orange', 'mango', 'lemon']

# %% [markdown]
# ***join***

# %%
# join
positive_numbers = [1, 2, 3, 4, 5]
zero = [0]
negative_numbers = [-5, -4, -3, -2, -1]
integers = negative_numbers + zero + positive_numbers
print(integers)
fruits = ['banana', 'orange', 'mango', 'lemon']
vegetables = ['Tomato', 'Potato', 'Cabbage', 'Onion', 'Carrot']
fruits_and_vegetables = fruits + vegetables
print(fruits_and_vegetables)

# %% [markdown]
# ***join with extend***

# %%
# join with extend
num1 = [0, 1, 2, 3]
num2 = [4, 5, 6]
num1.extend(num2)
print('Numbers:', num1)
negative_numbers = [-5, -4, -3, -2, -1]
positive_numbers = [1, 2, 3, 4, 5]
zero = [0]

# %%
negative_numbers.extend(zero)
negative_numbers.extend(positive_numbers)
print('Integers:', negative_numbers)
fruits = ['banana', 'orange', 'mango', 'lemon']
vegetables = ['Tomato', 'Potato', 'Cabbage', 'Onion', 'Carrot']
fruits.extend(vegetables)
print('Fruits and vegetables:', fruits)

# %% [markdown]
# ***count***

# %%
# count
fruits = ['banana', 'orange', 'mango', 'lemon']
print(fruits.count('orange'))   # 1
ages = [22, 19, 24, 25, 26, 24, 25, 24]
print(ages.count(24))           # 3

# %% [markdown]
# ***index***

# %%
# index
fruits = ['banana', 'orange', 'mango', 'lemon']
print(fruits.index('orange'))   # 1
ages = [22, 19, 24, 25, 26, 24, 25, 24]
print(ages.index(24))
# Reverse
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.reverse()
print(fruits.reverse())
ages = [22, 19, 24, 25, 26, 24, 25, 24]
ages.reverse()
print(ages.reverse())

# %% [markdown]
# ***sort***

# %%
# sort
fruits = ['banana', 'orange', 'mango', 'lemon']
fruits.sort()
print(fruits)
fruits.sort(reverse=True)
print(fruits)
ages = [22, 19, 24, 25, 26, 24, 25, 24]
ages.sort()
print(ages)
ages.sort(reverse=True)
print(ages)

# %% [markdown]
# # Exercises: Day 5

# %%
# 1. Exercises: Day 5
lst = []

# %%
# 2. Declare a list with more than 5 items
lst_names = ["abdallah", "Ali", "hicham", "hanae", "hmida"]

# %%
# 3. Find the length of your list
print(len(lst_names))
# Out:
# 5

# %%
# 4. Get the first item, the middle item and the last item of the list
print("the first one: ", lst_names[0])
print("the first middle : " , lst_names[len(lst_names) // 2] )
print("the first last : ", lst_names[-1])
# Out:
# the first one:  abdallah
# the first middle :  hicham
# the first last :  hmida

# %%
# 5. Declare a list called mixed_data_types, put your(name, age, height, marital status, address)

mixed_data_types = ["Abdallah","22","180","Single","Belfaa"]

# %%
# 6. Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 7. Print the list using print()

print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 8. Print the number of companies in the list

print(len(it_companies))
# Out:
# 7

# %%
# 9. Print the first, middle and last company

print("The first item :" , it_companies[0])
print("The middle item :" , it_companies[len(it_companies)//2])
print("The last item :" , it_companies[-1])
# Out:
# The first item : Facebook
# The middle item : Apple
# The last item : Amazon

# %%
# 10. Print the list after modifying one of the companies

print(it_companies[(len(it_companies)//2) + 1] )
# Out:
# IBM

# %%
# 11. Add an IT company to it_companies
print(it_companies + ["Anthropic"])
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Anthropic']

# %%
# 12. Insert an IT company in the middle of the companies list

it_companies.insert(len(it_companies)//2,"OpenAi")
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'OpenAi', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 13. Change one of the it_companies names to uppercase (IBM excluded!)
print(it_companies[4].upper())
# Out:
# APPLE

# %%
# 14. Join the it_companies with a string '#;  '
print("#".join(it_companies))
# Out:
# Facebook#Google#Microsoft#OpenAi#Apple#IBM#Oracle#Amazon

# %%
# 15. Check if a certain company exists in the it_companies list.
Anthropic = "Anthropic" in it_companies
print(Anthropic)
# Out:
# False

# %%
# 16. Sort the list using sort() method

it_companies.sort()
print(it_companies)
# Out:
# ['Amazon', 'Apple', 'Facebook', 'Google', 'IBM', 'Microsoft', 'OpenAi', 'Oracle']

# %%
# 17. Reverse the list in descending order using reverse() method

it_companies.sort(reverse=True)
print(it_companies)
# Out:
# ['Oracle', 'OpenAi', 'Microsoft', 'IBM', 'Google', 'Facebook', 'Apple', 'Amazon']

# %%
# 18. Slice out the first 3 companies from the list

print(it_companies[:3])
# Out:
# ['Oracle', 'OpenAi', 'Microsoft']

# %%
# 19. Slice out the last 3 companies from the list

print(it_companies[-3:])
# Out:
# ['Facebook', 'Apple', 'Amazon']

# %%
# 20. Slice out the middle IT company or companies from the list

print(it_companies[len(it_companies)//2])
# Out:
# Google

# %%
# 21. Remove the first IT company from the list


it_companies.pop(0)
print(it_companies)
# Out:
# ['IBM', 'Google', 'Facebook', 'Apple', 'Amazon']

# %%
# 22. Remove the middle IT company or companies from the list

it_companies.pop(len(it_companies)//2)
print(it_companies)
# Out:
# ['IBM', 'Google', 'Apple', 'Amazon']

# %%
# 23. Remove the last IT company from the list

it_companies.pop(-1)
print(it_companies)
# Out:
# ['IBM', 'Google', 'Apple']

# %%
# 24. Remove all IT companies from the list

it_companies.clear()
print(it_companies)
# Out:
# []

# %%
# 25. Destroy the IT companies list

del it_companies

# %%
# 26. Join the following lists:

front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

print(front_end + back_end)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %%
# 27.After joining the lists in question 26. 
# Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux.

full_stack = front_end + back_end
redux_index = full_stack.index('Redux')
full_stack.insert(redux_index + 1, 'Python')
full_stack.insert(redux_index + 2, 'SQL')
print(full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Python', 'SQL', 'Node', 'Express', 'MongoDB']

# %% [markdown]
# # Exercises: Level 2

# %%
# 1. The following is a list of 10 students ages:
# Sort the list and find the min and max age
# Add the min age and the max age again to the list
# Find the median age (one middle item or two middle items divided by two)
# Find the average age (sum of all items divided by their number )
# Find the range of the ages (max minus min)
# Compare the value of (min - average) and (max - average), use abs() method
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

ages.sort()
print(ages)
_min = min(ages)
_max = max(ages)
print("Min :" , _min)
print("Max :" , _max)
ages.append(_min)
ages.append(_max)
print(ages)
_middle = (ages[len(ages)//2 - 1] + ages[len(ages)//2]) / 2
print("Middle :", _middle)
avg = sum(ages) / len(ages)
print("Average :", avg)
age_range = max(ages) - min(ages)
print(age_range)
print(abs(_min - avg))
print(abs(_max - avg))
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]
# Min : 19
# Max : 26
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 19, 26]
# Middle : 24.0
# Average : 22.75
# 7
# 3.75
# 3.25

# %%
# 2. Find the middle country(ies) in the countries list
mid = len(countries) // 2
print(countries[mid - 1], countries[mid])  # both middle items
# Out:
# Estonia Denmark

# %%
print(len(countries)//2)
# Out:
# 2

# %%
# 3. Divide the countries list into two equal lists if it is even if not one more country for the first half.

n = len(countries)  // 2

if len(countries) % 2 == 0 :
    lst_1 = countries[:n]
    lst_2 = countries[n:]
else :
    lst_1 = countries[:n+1]
    lst_2 = countries[n+1:]
print(lst_1)
print(lst_2)
# Out:
# ['Finland', 'Estonia', 'Denmark']
# ['Sweden', 'Norway']

# %%
# 4. Unpack the first three countries and the rest as scandic countries.

countries = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']

first, second, third, *scandic_countries = countries

print(first)              # China
print(second)             # Russia
print(third)               # USA
print(scandic_countries)  # ['Finland', 'Sweden', 'Norway', 'Denmark']
# Out:
# China
# Russia
# USA
# ['Finland', 'Sweden', 'Norway', 'Denmark']
